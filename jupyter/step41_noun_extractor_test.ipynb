# %%
head = 'l30_r15'
directory = '../data/'
model_fname ='../models/Logistic + L2 (C=1.00) norm l30_r15.pkl'


import pickle    
from py.utils import load_data
from py.noun import TrainedNounExtractor

X, y, x_words, vocabs = load_data(head, directory)
with open(model_fname, 'rb') as f:
    classifier = pickle.load(f)
# Out:
# x shape = (15106, 2770)
# y shape = (15106,)
# # features = 2770
# # L words = 15106

# %%
coefficient = {vocabs[j]:coef for j, coef in enumerate(classifier.coef_[0])}

# %%
from config import sentence_fname
class Sentences:
    def __init__(self, fname):
        self.fname = fname
    def __iter__(self):
        with open(self.fname, encoding='utf-8') as f:
            for doc in f:
                yield doc.strip()

sentences = Sentences('../data/sentences_onlyhangle.txt')
noun_extractor = TrainedNounExtractor(coefficient)
scores = noun_extractor.extract(sentences)
# Out:
# lrgraph has been built. (#L= 173620, #R= 71297, #E=2022472), mem= 0.438 Gb
# compute branching entropy ... done
# computing noun score has been done.
# n_candidates= 62448
# n_nouns after substring processing= 52151
# n_nouns after compound processing= 48366

# %%
sorted_list = sorted(filter(lambda x:not type(x[1]) == tuple and len(x[0]) > 1, scores.items()), key=lambda x:x[1].frequency * x[1].score, reverse=True)[:500]
for noun, score in sorted_list:
    print('%s (s=%.2f, f=%d)' % (noun, score.score, score.frequency))
# Out:
# 우리 (s=2.51, f=44821)
# 사람 (s=2.00, f=53855)
# 자신 (s=4.37, f=16087)
# 사회 (s=3.59, f=19184)
# 하나 (s=3.22, f=18922)
# 때문 (s=2.09, f=28019)
# 자기 (s=4.00, f=13801)
# 한국 (s=3.26, f=16477)
# 문제 (s=2.88, f=17843)
# 생각 (s=1.46, f=31930)
# 사람들 (s=2.52, f=18332)
# 인간 (s=3.64, f=12364)
# 세계 (s=3.48, f=12362)
# 그녀 (s=2.69, f=15761)
# 미국 (s=3.69, f=10757)
# 소리 (s=3.24, f=11897)
# 이상 (s=3.25, f=11723)
# 그것 (s=1.76, f=21254)
# 모두 (s=3.45, f=10734)
# 시간 (s=2.76, f=13144)
# 것으 (s=2.99, f=12063)
# 문화 (s=3.68, f=9604)
# 이러 (s=3.31, f=10441)
# 정도 (s=2.76, f=11979)
# 일본 (s=3.23, f=10184)
# 어떤 (s=2.39, f=13572)
# 경제 (s=3.84, f=8355)
# 사이 (s=3.61, f=8705)
# 경우 (s=1.76, f=17191)
# 그들 (s=2.87, f=10513)
# 역사 (s=3.59, f=8286)
# 마음 (s=2.77, f=10643)
# 여자 (s=2.68, f=10822)
# 나라 (s=3.24, f=8903)
# 필요 (s=2.56, f=11273)
# 정치 (s=3.16, f=8911)
# 아이 (s=1.75, f=15748)
# 대학 (s=3.07, f=8678)
# 정부 (s=3.20, f=8110)
# 가장 (s=2.35, f=10956)
# 이야기 (s=2.80, f=9209)
# 머리 (s=3.99, f=6369)
# 다음 (s=2.12, f=11766)
# 사실 (s=1.73, f=14283)
# 의미 (s=2.77, f=8930)
# 있는 (s=0.37, f=65389)
# 시대 (s=3.83, f=6250)
# 다른 (s=1.48, f=15930)
# 관계 (s=2.81, f=8379)
# 얼굴 (s=2.68, f=8721)
# 더욱 (s=3.71, f=6172)
# 서울 (s=2.37, f=9662)
# 교육 (s=2.79, f=8205)
# 어머니 (s=2.52, f=9036)
# 동안 (s=2.96, f=7661)
# 않은 (s=3.28, f=6795)
# 중요 (s=2.80, f=7941)
# 정보 (s=4.07, f=5462)
# 연구 (s=2.67, f=8279)
# 전체 (s=4.64, f=4730)
# 여성 (s=2.72, f=8058)
# 학교 (s=2.82, f=7773)
# 국민 (s=3.63, f=6000)
# 아버지 (s=2.80, f=7747)
# 지금 (s=1.39, f=15475)
# 얘기 (s=2.39, f=8879)
# 국가 (s=3.29, f=6423)
# 아닌 (s=2.98, f=6825)
# 현대 (s=3.83, f=5278)
# 개인 (s=4.09, f=4944)
# 민족 (s=3.72, f=5409)
# 현재 (s=3.47, f=5805)
# 생활 (s=2.87, f=7005)
# 기업 (s=3.24, f=6109)
# 자리 (s=2.85, f=6920)
# 자체 (s=3.94, f=4889)
# 스스로 (s=4.65, f=4036)
# 일반 (s=3.62, f=5172)
# 남자 (s=2.61, f=7122)
# 선생 (s=2.51, f=7330)
# 지역 (s=2.97, f=6178)
# 문학 (s=2.91, f=6279)
# 세상 (s=2.97, f=6057)
# 당시 (s=3.97, f=4521)
# 결과 (s=3.03, f=5858)
# 중심 (s=3.60, f=4841)
# 생명 (s=3.87, f=4488)
# 사랑 (s=2.32, f=7504)
# 영화 (s=3.02, f=5746)
# 대부분 (s=4.23, f=4093)
# 이들 (s=2.51, f=6900)
# 모습 (s=2.43, f=7096)
# 중국 (s=3.01, f=5705)
# 운동 (s=2.80, f=6109)
# 현실 (s=2.79, f=6057)
# 아이들 (s=2.48, f=6752)
# 변화 (s=3.11, f=5353)
# 고개 (s=4.80, f=3445)
# 시민 (s=3.18, f=5171)
# 정신 (s=2.72, f=5995)
# 자연 (s=2.44, f=6658)
# 방법 (s=2.27, f=7113)
# 처음 (s=2.07, f=7779)
# 전화 (s=3.46, f=4570)
# 조선 (s=3.42, f=4602)
# 환경 (s=3.04, f=5154)
# 오늘 (s=1.88, f=8254)
# 내용 (s=2.57, f=5958)
# 하지 (s=1.15, f=13222)
# 공동 (s=4.53, f=3313)
# 북한 (s=3.49, f=4292)
# 과학 (s=3.00, f=4955)
# 친구 (s=2.36, f=6287)
# 이름 (s=2.43, f=6116)
# 언론 (s=3.31, f=4455)
# 최근 (s=3.35, f=4386)
# 언어 (s=3.38, f=4320)
# 프로 (s=2.84, f=5141)
# 대통령 (s=3.08, f=4665)
# 소설 (s=2.76, f=5155)
# 상대 (s=3.24, f=4373)
# 기술 (s=2.73, f=5180)
# 함께 (s=1.44, f=9747)
# 바람 (s=2.66, f=5257)
# 시장 (s=3.01, f=4635)
# 작품 (s=2.65, f=5204)
# 세기 (s=3.78, f=3617)
# 가슴 (s=3.14, f=4316)
# 이해 (s=2.12, f=6357)
# 이것 (s=1.59, f=8414)
# 최고 (s=5.24, f=2534)
# 수밖 (s=3.69, f=3587)
# 엄마 (s=2.64, f=4981)
# 가치 (s=3.80, f=3442)
# 사건 (s=2.88, f=4513)
# 당신 (s=2.65, f=4878)
# 신문 (s=2.66, f=4869)
# 사고 (s=3.58, f=3614)
# 컴퓨터 (s=3.60, f=3568)
# 이유 (s=2.15, f=5940)
# 시작 (s=1.00, f=12705)
# 각각 (s=5.66, f=2233)
# 대상 (s=2.91, f=4289)
# 효과 (s=4.03, f=3091)
# 의사 (s=3.17, f=3911)
# 회사 (s=3.07, f=3993)
# 각종 (s=6.39, f=1908)
# 과정 (s=2.34, f=5212)
# 관심 (s=2.81, f=4313)
# 이번 (s=2.05, f=5897)
# 거리 (s=3.50, f=3455)
# 과거 (s=3.82, f=3125)
# 차이 (s=3.47, f=3431)
# 지방 (s=3.11, f=3809)
# 만큼 (s=3.43, f=3448)
# 학생 (s=1.91, f=6179)
# 상황 (s=2.32, f=5074)
# 남편 (s=2.73, f=4309)
# 관련 (s=2.06, f=5628)
# 자유 (s=2.19, f=5284)
# 동시 (s=3.67, f=3150)
# 구조 (s=3.26, f=3539)
# 실제 (s=2.87, f=4023)
# 도시 (s=3.20, f=3597)
# 금융 (s=3.58, f=3209)
# 외국 (s=2.86, f=4016)
# 하다 (s=3.29, f=3477)
# 죽음 (s=3.03, f=3767)
# 가능 (s=1.62, f=7043)
# 기존 (s=6.18, f=1845)
# 상태 (s=2.46, f=4624)
# 산업 (s=3.50, f=3240)
# 예술 (s=2.58, f=4386)
# 활동 (s=2.50, f=4539)
# 지식 (s=3.06, f=3705)
# 약간 (s=4.88, f=2294)
# 다양 (s=3.07, f=3641)
# 작가 (s=3.17, f=3500)
# 노래 (s=3.12, f=3544)
# 나이 (s=3.23, f=3413)
# 발전 (s=2.12, f=5181)
# 형태 (s=3.22, f=3398)
# 완전 (s=3.43, f=3175)
# 광고 (s=3.19, f=3409)
# 나무 (s=2.90, f=3732)
# 제도 (s=3.31, f=3256)
# 역할 (s=2.62, f=4098)
# 영향 (s=2.75, f=3887)
# 목소리 (s=3.18, f=3350)
# 사회적 (s=3.39, f=3133)
# 방송 (s=2.66, f=3955)
# 하늘 (s=2.84, f=3703)
# 미래 (s=4.25, f=2469)
# 경기 (s=2.76, f=3800)
# 조사 (s=2.56, f=4050)
# 그림 (s=2.21, f=4696)
# 부분 (s=2.27, f=4561)
# 사용 (s=1.34, f=7686)
# 선생님 (s=2.12, f=4825)
# 의식 (s=2.69, f=3793)
# 단순 (s=3.36, f=3038)
# 민주 (s=2.23, f=4566)
# 전국 (s=4.18, f=2425)
# 마을 (s=3.05, f=3300)
# 대중 (s=3.42, f=2946)
# 신경 (s=2.63, f=3814)
# 존재 (s=1.94, f=5162)
# 이렇게 (s=0.80, f=12538)
# 전쟁 (s=3.01, f=3300)
# 아내 (s=2.86, f=3459)
# 아침 (s=2.52, f=3929)
# 전통 (s=2.91, f=3392)
# 무엇 (s=1.16, f=8438)
# 인사 (s=3.06, f=3197)
# 환자 (s=3.37, f=2900)
# 대화 (s=3.72, f=2604)
# 다리 (s=3.90, f=2482)
# 특별 (s=3.70, f=2612)
# 하루 (s=2.49, f=3837)
# 사상 (s=2.72, f=3518)
# 표현 (s=1.92, f=4944)
# 생산 (s=2.08, f=4551)
# 공부 (s=2.68, f=3528)
# 기능 (s=2.67, f=3521)
# 영국 (s=3.80, f=2471)
# 프랑스 (s=3.64, f=2574)
# 가족 (s=2.57, f=3638)
# 아기 (s=3.63, f=2571)
# 부모 (s=3.11, f=2977)
# 기회 (s=3.90, f=2364)
# 담배 (s=4.09, f=2251)
# 의료 (s=3.83, f=2400)
# 민중 (s=3.78, f=2420)
# 수준 (s=2.95, f=3096)
# 조직 (s=2.75, f=3310)
# 공공 (s=5.12, f=1775)
# 아들 (s=2.63, f=3452)
# 가능성 (s=2.89, f=3145)
# 정책 (s=3.12, f=2903)
# 일부 (s=1.71, f=5216)
# 상당 (s=3.47, f=2570)
# 어린 (s=1.96, f=4541)
# 자동 (s=3.46, f=2568)
# 은행 (s=2.87, f=3098)
# 것인 (s=1.70, f=5232)
# 프로그램 (s=3.12, f=2842)
# 경쟁 (s=2.55, f=3457)
# 교수 (s=2.29, f=3846)
# 주장 (s=1.53, f=5762)
# 서양 (s=4.18, f=2104)
# 바다 (s=3.41, f=2553)
# 구체적 (s=3.48, f=2491)
# 주인 (s=2.41, f=3591)
# 행동 (s=2.51, f=3440)
# 학생들 (s=2.93, f=2938)
# 분위기 (s=3.42, f=2517)
# 우리나라 (s=3.08, f=2794)
# 최대 (s=5.22, f=1645)
# 유럽 (s=3.52, f=2442)
# 자세 (s=3.26, f=2630)
# 성격 (s=2.83, f=3024)
# 그동안 (s=4.54, f=1879)
# 종교 (s=3.28, f=2598)
# 후보 (s=2.97, f=2869)
# 인류 (s=4.69, f=1799)
# 통일 (s=2.49, f=3383)
# 직접 (s=2.11, f=3990)
# 대표 (s=1.92, f=4370)
# 자료 (s=3.65, f=2298)
# 있었던 (s=2.70, f=3103)
# 자본 (s=3.08, f=2704)
# 결혼 (s=2.00, f=4158)
# 구체 (s=2.86, f=2910)
# 순간 (s=2.40, f=3469)
# 지구 (s=4.00, f=2079)
# 했던 (s=4.08, f=2035)
# 학문 (s=3.42, f=2428)
# 능력 (s=2.76, f=2999)
# 개발 (s=2.09, f=3946)
# 하며 (s=2.60, f=3177)
# 마지막 (s=2.88, f=2857)
# 사업 (s=2.61, f=3140)
# 달러 (s=3.91, f=2090)
# 오늘날 (s=3.49, f=2343)
# 우주 (s=3.82, f=2129)
# 음식 (s=2.60, f=3124)
# 남북 (s=3.54, f=2292)
# 전문 (s=2.06, f=3935)
# 현상 (s=2.23, f=3629)
# 평가 (s=2.03, f=3969)
# 대부 (s=1.90, f=4222)
# 절대 (s=3.11, f=2578)
# 반대 (s=2.44, f=3264)
# 준비 (s=2.47, f=3229)
# 인생 (s=3.38, f=2358)
# 인식 (s=2.18, f=3639)
# 노동 (s=2.04, f=3860)
# 집단 (s=3.24, f=2435)
# 중앙 (s=2.99, f=2618)
# 있어서 (s=1.43, f=5451)
# 투자 (s=2.70, f=2867)
# 억원 (s=3.41, f=2269)
# 노력 (s=2.18, f=3531)
# 분야 (s=3.07, f=2502)
# 단계 (s=2.80, f=2721)
# 독일 (s=3.44, f=2213)
# 경험 (s=2.45, f=3098)
# 감정 (s=3.03, f=2497)
# 모양 (s=1.67, f=4539)
# 이전 (s=3.26, f=2314)
# 개념 (s=2.53, f=2969)
# 요구 (s=1.82, f=4112)
# 주제 (s=3.29, f=2270)
# 기억 (s=2.10, f=3564)
# 이론 (s=2.50, f=2979)
# 목적 (s=2.48, f=2984)
# 만약 (s=3.87, f=1911)
# 대통 (s=1.57, f=4705)
# 이용 (s=1.54, f=4803)
# 논리 (s=3.05, f=2425)
# 독자 (s=3.01, f=2441)
# 설명 (s=1.47, f=4972)
# 태도 (s=2.86, f=2538)
# 방향 (s=2.84, f=2545)
# 작업 (s=2.54, f=2824)
# 서비스 (s=4.22, f=1700)
# 정치적 (s=3.31, f=2166)
# 그렇게 (s=0.72, f=9978)
# 가정 (s=2.39, f=2991)
# 눈물 (s=2.97, f=2406)
# 일종 (s=5.72, f=1251)
# 것들 (s=2.25, f=3171)
# 주변 (s=3.34, f=2132)
# 방식 (s=2.57, f=2773)
# 위치 (s=3.27, f=2171)
# 옛날 (s=2.86, f=2482)
# 주요 (s=3.93, f=1804)
# 표정 (s=2.59, f=2723)
# 시기 (s=2.78, f=2537)
# 아래 (s=1.84, f=3822)
# 반면 (s=3.73, f=1884)
# 권력 (s=3.30, f=2121)
# 평화 (s=3.39, f=2066)
# 게다 (s=5.08, f=1377)
# 교사 (s=2.72, f=2572)
# 단체 (s=3.18, f=2196)
# 참여 (s=2.10, f=3317)
# 우리들 (s=2.97, f=2352)
# 있지 (s=1.03, f=6758)
# 어깨 (s=4.19, f=1656)
# 시절 (s=3.08, f=2253)
# 종류 (s=4.17, f=1657)
# 규모 (s=3.73, f=1851)
# 오후 (s=2.90, f=2368)
# 선거 (s=3.06, f=2244)
# 인물 (s=2.47, f=2768)
# 입장 (s=2.05, f=3326)
# 체제 (s=3.72, f=1835)
# 들어 (s=0.28, f=23888)
# 벤처 (s=3.82, f=1777)
# 일반적 (s=3.35, f=2021)
# 공간 (s=2.70, f=2500)
# 일정 (s=3.24, f=2083)
# 기분 (s=2.55, f=2638)
# 지도 (s=2.32, f=2896)
# 음악 (s=2.66, f=2515)
# 주위 (s=4.07, f=1642)
# 상품 (s=2.99, f=2229)
# 일제 (s=4.35, f=1527)
# 자동차 (s=3.46, f=1918)
# 결정 (s=1.50, f=4406)
# 비슷 (s=2.75, f=2413)
# 장애 (s=3.43, f=1927)
# 기본 (s=2.18, f=3020)
# 그런데 (s=0.83, f=7885)
# 행위 (s=2.82, f=2330)
# 나중 (s=3.11, f=2111)
# 점점 (s=3.81, f=1712)
# 도움 (s=3.23, f=2020)
# 행사 (s=2.88, f=2254)
# 집안 (s=3.23, f=2010)
# 도대체 (s=5.09, f=1271)
# 느낌 (s=2.41, f=2676)
# 편지 (s=3.65, f=1766)
# 구성 (s=1.74, f=3706)
# 차원 (s=2.89, f=2227)
# 영어 (s=3.19, f=2016)
# 회의 (s=3.23, f=1994)
# 관리 (s=2.39, f=2687)
# 마리 (s=3.94, f=1626)
# 의견 (s=2.79, f=2295)
# 있던 (s=1.38, f=4632)
# 지난 (s=0.71, f=8968)
# 한계 (s=4.02, f=1581)
# 차례 (s=3.02, f=2097)
# 만원 (s=2.83, f=2240)
# 기준 (s=2.79, f=2268)
# 선택 (s=2.19, f=2871)
# 한편 (s=1.52, f=4134)
# 경영 (s=2.31, f=2709)
# 아파트 (s=3.09, f=2024)
# 최초 (s=5.16, f=1211)
# 지배 (s=2.13, f=2935)
# 잘못 (s=1.80, f=3459)
# 계획 (s=1.84, f=3394)
# 개혁 (s=2.98, f=2092)
# 경찰 (s=2.05, f=3029)
# 비롯 (s=2.32, f=2665)
# 행정 (s=3.48, f=1777)
# 냄새 (s=3.79, f=1630)
# 치료 (s=2.93, f=2099)
# 지원 (s=1.90, f=3229)
# 사진 (s=2.24, f=2737)
# 철학 (s=2.43, f=2516)
# 피해 (s=2.68, f=2274)
# 그러 (s=0.13, f=46438)
# 기계 (s=3.30, f=1841)
# 진정 (s=3.32, f=1827)
# 한번 (s=1.32, f=4600)
# 저녁 (s=2.22, f=2720)
# 있음 (s=2.44, f=2463)
# 책임 (s=1.87, f=3213)
# 문장 (s=2.87, f=2095)
# 있기 (s=1.44, f=4164)
# 이미지 (s=3.66, f=1634)
# 형식 (s=2.87, f=2064)
# 정확 (s=2.49, f=2381)
# 분명 (s=1.43, f=4126)
# 비판 (s=2.09, f=2822)
# 기사 (s=3.40, f=1728)
# 인기 (s=3.93, f=1496)
# 발표 (s=1.89, f=3099)
# 군사 (s=3.46, f=1691)
# 버스 (s=3.46, f=1690)
# 고향 (s=2.86, f=2039)
# 주체 (s=2.86, f=2039)
# 아직 (s=0.83, f=7057)
# 텔레비 (s=3.27, f=1780)
# 내부 (s=3.43, f=1696)
# 하는 (s=0.19, f=30247)
# 대체 (s=2.78, f=2082)
# 자금 (s=3.24, f=1782)
# 논의 (s=2.61, f=2209)
# 물질 (s=3.24, f=1778)
# 제품 (s=3.09, f=1864)
# 여행 (s=2.28, f=2526)
# 위기 (s=3.71, f=1549)
# 당연 (s=2.45, f=2342)
# 근대 (s=3.17, f=1809)
# 고객 (s=2.93, f=1951)
# 의원 (s=2.28, f=2509)
# 부정 (s=2.18, f=2598)
# 따위 (s=3.67, f=1541)
# 일상 (s=3.66, f=1544)
# 한국인 (s=3.66, f=1544)
# 원인 (s=2.37, f=2384)
# 감독 (s=2.88, f=1959)
# 성장 (s=2.17, f=2594)
# 건강 (s=2.56, f=2201)
# 동물 (s=2.68, f=2092)
# 적극적 (s=3.39, f=1654)
# 수사 (s=3.46, f=1612)
# 사태 (s=3.73, f=1495)
# 성공 (s=2.00, f=2781)
# 남녀 (s=4.60, f=1205)
# 조건 (s=2.54, f=2179)
# 기초 (s=3.36, f=1647)
# 서구 (s=4.53, f=1219)
# 질서 (s=3.72, f=1480)
# 농민 (s=2.51, f=2195)
# 창조 (s=2.56, f=2150)
# 어린이 (s=2.68, f=2041)
# 충분 (s=2.24, f=2445)
# 요소 (s=3.01, f=1816)
# 허리 (s=4.12, f=1323)
# 웃음 (s=2.74, f=1989)
# 체계 (s=3.37, f=1613)
# 자본주의 (s=3.93, f=1380)
# 근거 (s=3.06, f=1771)
# 누군가 (s=4.41, f=1226)
# 기록 (s=1.71, f=3155)
# 그냥 (s=1.01, f=5315)
# 속으 (s=2.88, f=1866)
# 뉴스 (s=3.55, f=1512)
# 기관 (s=2.50, f=2147)
# 정당 (s=2.98, f=1796)
# 단지 (s=3.32, f=1611)
# 민간 (s=3.71, f=1441)
# 특정 (s=4.06, f=1313)
# 커피 (s=3.70, f=1442)
# 건물 (s=2.60, f=2044)
# 업무 (s=3.98, f=1335)
# 발생 (s=1.68, f=3160)
# 남성 (s=2.53, f=2091)
# 자식 (s=2.10, f=2512)
# 갔다 (s=1.91, f=2759)
# 전자 (s=2.76, f=1904)
# 연기 (s=2.94, f=1788)
# 불교 (s=3.65, f=1436)
# 전기 (s=3.63, f=1442)

# %%
sorted_list = sorted(filter(lambda x:not type(x[1]) == tuple and len(x[0]) > 1, scores.items()), key=lambda x:x[1].score, reverse=True)[:500]
for noun, score in sorted_list:
    print('%s (s=%.2f, f=%d)' % (noun, score.score, score.frequency))
# Out:
# 외짝 (s=6.46, f=11)
# 연쇄살인 (s=6.46, f=18)
# 혼외 (s=6.46, f=13)
# 선거관리 (s=6.46, f=13)
# 영과 (s=6.46, f=10)
# 초유 (s=6.46, f=15)
# 학제간 (s=6.46, f=13)
# 한독 (s=6.46, f=21)
# 백민 (s=6.46, f=10)
# 월하 (s=6.46, f=12)
# 정책자 (s=6.46, f=13)
# 병참 (s=6.46, f=20)
# 각급 (s=6.46, f=66)
# 초현실 (s=6.46, f=58)
# 오덴 (s=6.46, f=13)
# 린다 (s=6.46, f=28)
# 마샬 (s=6.46, f=23)
# 임원십육지 (s=6.46, f=25)
# 크렘린 (s=6.46, f=18)
# 이향 (s=6.46, f=11)
# 영업본부 (s=6.46, f=13)
# 아데나워 (s=6.46, f=10)
# 방송문화 (s=6.46, f=12)
# 내부자 (s=6.46, f=14)
# 정읍사 (s=6.46, f=35)
# 로써 (s=6.46, f=42)
# 쌍마 (s=6.46, f=11)
# 생산자물가 (s=6.46, f=19)
# 중앙정보국 (s=6.46, f=11)
# 토지분급 (s=6.46, f=10)
# 페레 (s=6.46, f=50)
# 그들끼리 (s=6.46, f=11)
# 아홉번째 (s=6.46, f=11)
# 멸망시 (s=6.46, f=23)
# 사회정 (s=6.46, f=86)
# 신윤복 (s=6.46, f=11)
# 영어강 (s=6.46, f=10)
# 서낭 (s=6.46, f=31)
# 한낱 (s=6.46, f=127)
# 오륙십 (s=6.46, f=16)
# 주간한국 (s=6.46, f=13)
# 반민 (s=6.46, f=174)
# 유즈 (s=6.46, f=22)
# 비체계 (s=6.46, f=14)
# 나노 (s=6.46, f=21)
# 세브란스 (s=6.46, f=25)
# 희대 (s=6.46, f=17)
# 열역학 (s=6.46, f=30)
# 순위항목 (s=6.46, f=12)
# 불굴 (s=6.46, f=20)
# 파죽 (s=6.46, f=10)
# 양질 (s=6.46, f=69)
# 청홍 (s=6.46, f=18)
# 소수인 (s=6.46, f=24)
# 광통신 (s=6.46, f=10)
# 아방 (s=6.46, f=70)
# 천혜 (s=6.46, f=37)
# 노트르담 (s=6.46, f=11)
# 문화교호간 (s=6.46, f=67)
# 토말 (s=6.46, f=12)
# 원뿔 (s=6.46, f=12)
# 노재헌 (s=6.46, f=10)
# 사중 (s=6.46, f=17)
# 국소 (s=6.46, f=79)
# 반골 (s=6.46, f=11)
# 요주 (s=6.46, f=13)
# 반씩 (s=6.46, f=20)
# 육당 (s=6.46, f=11)
# 부존 (s=6.46, f=11)
# 의료분쟁조정 (s=6.46, f=26)
# 란상 (s=6.46, f=10)
# 구로구 (s=6.46, f=34)
# 스탠다드 (s=6.46, f=36)
# 무반 (s=6.46, f=34)
# 새턴 (s=6.46, f=14)
# 수간 (s=6.46, f=12)
# 본모 (s=6.46, f=13)
# 미기입 (s=6.46, f=12)
# 한국대학교 (s=6.46, f=10)
# 농공 (s=6.46, f=16)
# 대한상 (s=6.46, f=32)
# 샤를 (s=6.46, f=42)
# 신강 (s=6.46, f=11)
# 줄리어스 (s=6.46, f=11)
# 일개 (s=6.46, f=82)
# 봉정사 (s=6.46, f=20)
# 피개 (s=6.46, f=14)
# 국가주 (s=6.46, f=69)
# 탈자본주 (s=6.46, f=21)
# 비정형 (s=6.46, f=12)
# 수개 (s=6.46, f=56)
# 구운몽 (s=6.46, f=35)
# 무호흡 (s=6.46, f=47)
# 화랭이패 (s=6.46, f=11)
# 초감각 (s=6.46, f=10)
# 경제주 (s=6.46, f=56)
# 위자 (s=6.46, f=38)
# 가계신용 (s=6.46, f=14)
# 피파 (s=6.46, f=12)
# 가향 (s=6.46, f=22)
# 전대미문 (s=6.46, f=17)
# 박일채 (s=6.46, f=64)
# 국가교호간 (s=6.46, f=15)
# 런닝머신 (s=6.46, f=10)
# 교보증권 (s=6.46, f=13)
# 알과 (s=6.46, f=20)
# 석박사 (s=6.46, f=15)
# 궁여 (s=6.46, f=20)
# 라오 (s=6.46, f=235)
# 박광태 (s=6.46, f=11)
# 이크 (s=6.46, f=20)
# 아나톨리아 (s=6.46, f=10)
# 절호 (s=6.46, f=39)
# 지레 (s=6.46, f=116)
# 전업주 (s=6.46, f=19)
# 빈사 (s=6.46, f=12)
# 서너번 (s=6.46, f=16)
# 육조 (s=6.46, f=37)
# 파초 (s=6.46, f=10)
# 민흘림 (s=6.46, f=15)
# 칠보 (s=6.46, f=15)
# 선제 (s=6.46, f=127)
# 함경남도 (s=6.46, f=19)
# 경기민요 (s=6.46, f=10)
# 요론트 (s=6.46, f=78)
# 천일야화 (s=6.46, f=15)
# 한국고대 (s=6.46, f=10)
# 오종 (s=6.46, f=12)
# 창경 (s=6.46, f=69)
# 이정연씨 (s=6.46, f=22)
# 현도 (s=6.46, f=11)
# 엘리아 (s=6.46, f=14)
# 인민민주주 (s=6.46, f=16)
# 쌍마자동차 (s=6.46, f=10)
# 재크 (s=6.46, f=14)
# 넝마주이 (s=6.46, f=10)
# 로버트 (s=6.46, f=188)
# 김영동 (s=6.46, f=10)
# 한국미술 (s=6.46, f=20)
# 필생 (s=6.46, f=13)
# 허혈성 (s=6.46, f=11)
# 이바노프 (s=6.46, f=13)
# 워렌 (s=6.46, f=13)
# 야누스 (s=6.46, f=10)
# 핵확산금지조약 (s=6.46, f=14)
# 자파 (s=6.46, f=14)
# 유클리드 (s=6.46, f=48)
# 고야 (s=6.46, f=11)
# 김중권 (s=6.46, f=19)
# 당중앙위원회 (s=6.46, f=28)
# 광진구 (s=6.46, f=14)
# 장상 (s=6.46, f=106)
# 매번 (s=6.46, f=141)
# 안데스 (s=6.46, f=12)
# 함북 (s=6.46, f=10)
# 트윈 (s=6.46, f=14)
# 거국 (s=6.46, f=28)
# 신문윤리강령 (s=6.46, f=18)
# 우국 (s=6.46, f=11)
# 인터컨티넨탈 (s=6.46, f=17)
# 권영길 (s=6.46, f=16)
# 서울지방 (s=6.46, f=27)
# 아라비안나이트 (s=6.46, f=20)
# 하드코어 (s=6.46, f=10)
# 지오그래픽 (s=6.46, f=16)
# 다민족 (s=6.46, f=14)
# 라일 (s=6.46, f=30)
# 암묵 (s=6.46, f=41)
# 이인국 (s=6.46, f=104)
# 최현배 (s=6.46, f=10)
# 고미 (s=6.46, f=23)
# 옥황 (s=6.46, f=11)
# 저스틴 (s=6.46, f=10)
# 반나 (s=6.46, f=57)
# 김근태 (s=6.46, f=26)
# 한국기독교 (s=6.46, f=14)
# 나프타 (s=6.46, f=12)
# 건설기 (s=6.46, f=12)
# 최단 (s=6.46, f=27)
# 무령왕 (s=6.46, f=16)
# 법률구조 (s=6.46, f=22)
# 외향 (s=6.46, f=39)
# 코스닥증권 (s=6.46, f=12)
# 가와 (s=6.46, f=36)
# 조봉암 (s=6.46, f=11)
# 태환 (s=6.46, f=18)
# 통상교섭본부 (s=6.46, f=10)
# 테네시 (s=6.46, f=20)
# 혈중 (s=6.46, f=30)
# 안철수 (s=6.46, f=14)
# 구포 (s=6.46, f=13)
# 양귀자 (s=6.46, f=12)
# 항일 (s=6.46, f=146)
# 덕원 (s=6.46, f=15)
# 몇발 (s=6.46, f=11)
# 통합전 (s=6.46, f=10)
# 지역환경 (s=6.46, f=14)
# 그런대로 (s=6.46, f=189)
# 히포 (s=6.46, f=13)
# 푸나 (s=6.46, f=16)
# 제야 (s=6.46, f=12)
# 우르 (s=6.46, f=184)
# 응분 (s=6.46, f=30)
# 사정기관 (s=6.46, f=10)
# 새한 (s=6.46, f=32)
# 타종 (s=6.46, f=17)
# 까자 (s=6.46, f=12)
# 진초록 (s=6.46, f=10)
# 외환수급 (s=6.46, f=14)
# 김덕수 (s=6.46, f=17)
# 해마다 (s=6.46, f=401)
# 도광 (s=6.46, f=10)
# 경동맥동 (s=6.46, f=13)
# 앨리 (s=6.46, f=43)
# 하루종일 (s=6.46, f=135)
# 대학강 (s=6.46, f=11)
# 페스 (s=6.46, f=165)
# 기화신령 (s=6.46, f=11)
# 맨하탄 (s=6.46, f=15)
# 경영상 (s=6.46, f=33)
# 경남도 (s=6.46, f=15)
# 밀라 (s=6.46, f=17)
# 다층 (s=6.46, f=23)
# 뇌동맥 (s=6.46, f=12)
# 상호주 (s=6.46, f=39)
# 모스 (s=6.46, f=271)
# 제반 (s=6.46, f=171)
# 이혜경 (s=6.46, f=13)
# 활동계획 (s=6.46, f=19)
# 반부 (s=6.46, f=30)
# 탐관 (s=6.46, f=12)
# 도큐 (s=6.46, f=12)
# 한국산업 (s=6.46, f=16)
# 백열 (s=6.46, f=48)
# 한국과학기술 (s=6.46, f=50)
# 미체험 (s=6.46, f=25)
# 매스 (s=6.46, f=414)
# 고부간 (s=6.46, f=20)
# 인간중심 (s=6.46, f=19)
# 루츠 (s=6.46, f=11)
# 근대민족 (s=6.46, f=14)
# 화공품 (s=6.46, f=20)
# 연의 (s=6.46, f=31)
# 보슈 (s=6.46, f=26)
# 로부터 (s=6.46, f=142)
# 우랄 (s=6.46, f=18)
# 보라매 (s=6.46, f=31)
# 하바로프 (s=6.46, f=49)
# 성동구 (s=6.46, f=34)
# 벽산 (s=6.46, f=13)
# 업무협 (s=6.46, f=18)
# 유종호 (s=6.46, f=15)
# 재판과정에서 (s=6.46, f=16)
# 아이스하키 (s=6.46, f=16)
# 마을공동 (s=6.46, f=14)
# 중외 (s=6.46, f=12)
# 각권 (s=6.46, f=26)
# 갑상선 (s=6.46, f=45)
# 운동확산 (s=6.46, f=11)
# 우리들끼리 (s=6.46, f=10)
# 경부고속철도 (s=6.46, f=20)
# 일렉트로닉 (s=6.46, f=10)
# 간척사 (s=6.46, f=29)
# 아사히 (s=6.46, f=64)
# 김우중 (s=6.46, f=37)
# 랄프 (s=6.46, f=10)
# 범패 (s=6.46, f=57)
# 도범 (s=6.46, f=10)
# 세계여성 (s=6.46, f=14)
# 레포 (s=6.46, f=50)
# 뿔뿔이 (s=6.46, f=63)
# 시온 (s=6.46, f=13)
# 영화진흥 (s=6.46, f=15)
# 브린 (s=6.46, f=10)
# 완전식 (s=6.46, f=23)
# 덮어놓고 (s=6.46, f=68)
# 사회심리 (s=6.46, f=20)
# 사회체 (s=6.46, f=60)
# 두대 (s=6.46, f=11)
# 방신영 (s=6.46, f=10)
# 여타 (s=6.46, f=155)
# 학생처 (s=6.46, f=13)
# 아름드리 (s=6.46, f=32)
# 일렉트릭 (s=6.46, f=15)
# 지용 (s=6.46, f=44)
# 필요불가 (s=6.46, f=16)
# 생면 (s=6.46, f=26)
# 안암 (s=6.46, f=23)
# 현종 (s=6.46, f=18)
# 차렷 (s=6.46, f=13)
# 페레스 (s=6.46, f=41)
# 아더 (s=6.46, f=25)
# 이개 (s=6.46, f=24)
# 만반 (s=6.46, f=26)
# 최고인민회 (s=6.46, f=20)
# 일생일대 (s=6.46, f=11)
# 국제법상 (s=6.46, f=16)
# 문화주 (s=6.46, f=24)
# 자와 (s=6.46, f=100)
# 뭇사람 (s=6.46, f=18)
# 피천득 (s=6.46, f=12)
# 프란체스코 (s=6.46, f=10)
# 미증유 (s=6.46, f=10)
# 일련 (s=6.44, f=347)
# 본연 (s=6.43, f=108)
# 저마다 (s=6.43, f=330)
# 소기 (s=6.42, f=56)
# 각종 (s=6.39, f=1908)
# 무소불위 (s=6.33, f=18)
# 불치 (s=6.32, f=61)
# 구시대 (s=6.32, f=29)
# 윤이상 (s=6.31, f=29)
# 이익집단간 (s=6.27, f=16)
# 의료전달체계 (s=6.27, f=10)
# 마르케스 (s=6.23, f=16)
# 공공의료 (s=6.23, f=137)
# 네개 (s=6.23, f=10)
# 할부금융회사 (s=6.23, f=15)
# 특단 (s=6.22, f=12)
# 특유 (s=6.22, f=393)
# 어제오늘 (s=6.19, f=12)
# 선승제 (s=6.19, f=10)
# 프론티어 (s=6.19, f=12)
# 레테 (s=6.19, f=14)
# 패스트푸드 (s=6.19, f=58)
# 고용구조 (s=6.19, f=10)
# 벤허 (s=6.19, f=18)
# 연구계획서 (s=6.19, f=11)
# 기존 (s=6.18, f=1845)
# 한떼 (s=6.17, f=14)
# 외화부채 (s=6.16, f=11)
# 반벌거숭이 (s=6.16, f=16)
# 각부 (s=6.16, f=18)
# 무형 (s=6.15, f=89)
# 정체불명 (s=6.15, f=28)
# 국민총생산 (s=6.14, f=24)
# 약사집단 (s=6.13, f=12)
# 각기 (s=6.12, f=586)
# 서로마 (s=6.12, f=18)
# 기술주 (s=6.12, f=22)
# 인민경제 (s=6.12, f=11)
# 수송장비 (s=6.12, f=18)
# 국가사회 (s=6.12, f=48)
# 하등 (s=6.11, f=85)
# 의약일체 (s=6.10, f=28)
# 원폭 (s=6.10, f=37)
# 호밀밭 (s=6.09, f=13)
# 한의대생 (s=6.07, f=15)
# 율리시즈 (s=6.07, f=22)
# 구북구 (s=6.07, f=16)
# 극미 (s=6.06, f=10)
# 그간 (s=6.05, f=253)
# 프랑크푸르트학파 (s=6.04, f=14)
# 생면부지 (s=6.03, f=22)
# 동급 (s=6.02, f=16)
# 고액 (s=6.02, f=68)
# 슈트라우스 (s=6.01, f=13)
# 사회지도층 (s=6.01, f=14)
# 반간폭 (s=6.01, f=19)
# 리타 (s=6.00, f=14)
# 조국광복회 (s=6.00, f=10)
# 아수라 (s=6.00, f=44)
# 솔거 (s=6.00, f=10)
# 만병통치 (s=6.00, f=18)
# 조흥금고 (s=6.00, f=15)
# 반문화 (s=6.00, f=16)
# 온실가스 (s=6.00, f=15)
# 충주시 (s=6.00, f=11)
# 정부간 (s=6.00, f=47)
# 만분 (s=5.99, f=20)
# 업무상 (s=5.98, f=38)
# 자사 (s=5.97, f=149)
# 혁명기 (s=5.95, f=13)
# 콘래드 (s=5.95, f=10)
# 고품질 (s=5.95, f=44)
# 나문재 (s=5.94, f=13)
# 회심 (s=5.93, f=48)
# 막돌허튼층쌓기 (s=5.92, f=20)
# 뭉크 (s=5.92, f=40)
# 외간 (s=5.92, f=26)
# 볼프 (s=5.92, f=14)
# 개개 (s=5.91, f=289)
# 홍적세 (s=5.91, f=14)
# 모잠비크 (s=5.91, f=15)
# 알튀세 (s=5.91, f=18)
# 요양급여 (s=5.91, f=22)
# 여가지 (s=5.91, f=11)
# 미키마우스 (s=5.91, f=12)
# 매일매일 (s=5.90, f=94)
# 오즈 (s=5.89, f=15)
# 여년간 (s=5.89, f=70)
# 고율 (s=5.88, f=19)
# 건강상 (s=5.88, f=38)
# 전략상 (s=5.88, f=11)
# 청운 (s=5.87, f=47)
# 낙찰가 (s=5.87, f=10)
# 죽느냐 (s=5.87, f=21)
# 절대다수 (s=5.87, f=15)
# 모짜르트 (s=5.87, f=15)
# 반외세 (s=5.87, f=15)
# 한국음악 (s=5.86, f=12)
# 농수산물 (s=5.86, f=22)
# 일본간 (s=5.86, f=12)
# 재정상 (s=5.86, f=17)
# 백분 (s=5.86, f=36)
# 불수 (s=5.85, f=39)
# 파우어 (s=5.85, f=10)
# 신용리스크 (s=5.85, f=26)
# 제곱킬로미터 (s=5.82, f=13)
# 원시토기시대 (s=5.82, f=14)
# 외방 (s=5.81, f=20)
# 실러 (s=5.81, f=11)
# 탄화수소 (s=5.81, f=13)
# 텔레커뮤니케이션 (s=5.80, f=11)
# 이출 (s=5.80, f=10)
# 반만년 (s=5.80, f=13)
# 황야 (s=5.80, f=89)
# 작금 (s=5.78, f=40)
# 폭발시 (s=5.78, f=20)
# 한국개발연구원 (s=5.78, f=25)
# 만고 (s=5.78, f=35)
# 새발 (s=5.78, f=14)
# 심훈 (s=5.78, f=15)
# 문화예술계 (s=5.78, f=10)
# 크리스테바 (s=5.78, f=10)
# 수리탐구 (s=5.77, f=14)
# 평등주의 (s=5.77, f=11)
# 대퇴 (s=5.77, f=29)
# 작가주의 (s=5.77, f=10)
# 강북구 (s=5.77, f=15)
# 클라크 (s=5.77, f=33)
# 기회주의자 (s=5.77, f=10)
# 마이스터 (s=5.77, f=11)
# 한일국교 (s=5.77, f=15)
# 웨일스 (s=5.77, f=11)
# 이석희 (s=5.77, f=17)
# 박정자 (s=5.77, f=12)
# 교자 (s=5.77, f=13)
# 한국기 (s=5.77, f=80)
# 하얏트 (s=5.77, f=19)
# 신용정보 (s=5.77, f=23)
# 연방국가 (s=5.77, f=16)
# 일본사 (s=5.77, f=72)
# 뿌리내리기 (s=5.77, f=11)
# 여성환경활동가 (s=5.77, f=13)
# 의료보호 (s=5.77, f=13)
# 통화관리 (s=5.77, f=14)
# 폴크 (s=5.77, f=34)
# 금오신화 (s=5.77, f=28)
# 매니지먼트 (s=5.77, f=20)
# 포레 (s=5.77, f=52)
# 만원어치 (s=5.77, f=11)
# 노사정위 (s=5.77, f=10)
# 고차원 (s=5.77, f=28)
# 재래 (s=5.77, f=187)
# 억대 (s=5.76, f=42)
# 비련 (s=5.74, f=24)
# 민주주의민족전선 (s=5.74, f=15)
# 혼신 (s=5.74, f=63)
# 수백명 (s=5.74, f=27)
# 프랑크 (s=5.74, f=162)
# 전자방식 (s=5.73, f=19)
# 무정형 (s=5.73, f=12)
# 마상 (s=5.73, f=19)
# 일종 (s=5.72, f=1251)
# 의료재 (s=5.72, f=49)
# 각고 (s=5.71, f=36)
# 남녘 (s=5.71, f=20)
# 수십개 (s=5.71, f=13)
# 진보진영 (s=5.70, f=27)
# 법률서비스 (s=5.70, f=14)
# 종래 (s=5.69, f=384)
# 당대 (s=5.69, f=439)
# 안견 (s=5.68, f=37)
# 세로토닌 (s=5.68, f=24)
# 대용량 (s=5.68, f=14)
# 권언유착 (s=5.68, f=12)
# 한바탕 (s=5.68, f=275)
# 무위자연 (s=5.67, f=10)
# 신탁회계 (s=5.67, f=15)
# 수천억원 (s=5.67, f=10)
# 생로병사 (s=5.67, f=18)
# 각각 (s=5.66, f=2233)
# 저간 (s=5.66, f=27)
# 망향 (s=5.66, f=15)
# 민족구성원 (s=5.66, f=13)
# 구국 (s=5.65, f=48)
# 다도해 (s=5.64, f=12)
# 이징 (s=5.64, f=14)
# 천분 (s=5.64, f=20)
# 상등 (s=5.64, f=17)
# 몇대 (s=5.64, f=21)
# 홀소리 (s=5.64, f=10)
# 배뇨 (s=5.64, f=25)
# 올림포스 (s=5.63, f=11)
# 일체 (s=5.62, f=592)
# 의약생활관계 (s=5.62, f=19)
# 백제시대 (s=5.61, f=19)
# 여성계 (s=5.61, f=32)
# 형형색색 (s=5.61, f=15)
