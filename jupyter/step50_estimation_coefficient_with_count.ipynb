# %%
head = 'l10_r10'
directory = '../data/'

from py.utils import load_data
from py.noun import TrainedNounExtractor

X, y, x_words, vocabs = load_data(head, directory)
# Out:
# x shape = (31546, 3515)
# y shape = (31546,)
# # features = 3515
# # L words = 31546

# %% [markdown]
# ## dev

# %%
def lr_to_coefficient(X, y, vocabs):
    from collections import namedtuple
    Info = namedtuple('Info', 'coef count')
    X_frequency = [v[0] for v in X.sum(axis=1).tolist()]
    n_pos = sum([v for v, label in zip(X_frequency, y) if label == 1])
    n_neg = sum([v for v, label in zip(X_frequency, y) if label == -1])
    print('(pos= %.3f, neg= %.3f)' % (n_pos/(n_pos+n_neg), n_neg/(n_pos+n_neg)))
    
    X_pos = X[[i for i, label in enumerate(y) if label == 1]]
    X_neg = X[[i for i, label in enumerate(y) if label == -1]]
    feature_pos_frequency = X_pos.sum(axis=0).tolist()[0]
    feature_neg_frequency = X_neg.sum(axis=0).tolist()[0]
    
    vocab_frequency = X.sum(axis=0).tolist()[0]
    neg_factor = n_pos / n_neg
    score = lambda p,n: (p - n * neg_factor) / (p + n * neg_factor)
    coefficient = [score(p,n) for p, n in zip(feature_pos_frequency, feature_neg_frequency)]
    coefficient = {vocab:Info(coef, count) for count, vocab, coef in zip(vocab_frequency, vocabs, coefficient)}
    return coefficient

# %% [markdown]
# ## test

# %%
from py.rcoef import lr_to_coefficient
from py.utils import save_lr_coefficient
from py.utils import load_lr_coefficient

# %%
coefficient = lr_to_coefficient(X, y, vocabs)
# Out:
# (pos= 0.724, neg= 0.276)

# %%
save_lr_coefficient(coefficient, './rcoef.pkl')

# %%
coefficient = load_lr_coefficient('./rcoef.pkl', as_coef_dict=False)
sorted(filter(lambda x:abs(x[1][0]) < 0.9, coefficient.items()), key=lambda x:x[1], reverse=False)[:20]
# Out:
# [('낸', Info(coef=-0.8972826917901976, count=337)),
#  ('내야', Info(coef=-0.8969513146935133, count=56)),
#  ('선', Info(coef=-0.8953956843389466, count=647)),
#  ('수', Info(coef=-0.8912857765304226, count=99)),
#  ('말', Info(coef=-0.8894625978993094, count=15)),
#  ('나가서', Info(coef=-0.8894625978993094, count=15)),
#  ('내려고', Info(coef=-0.8894625978993094, count=15)),
#  ('올리는', Info(coef=-0.8894625978993094, count=15)),
#  ('잘', Info(coef=-0.8894625978993094, count=30)),
#  ('려니', Info(coef=-0.8860528883070529, count=124)),
#  ('놓고', Info(coef=-0.8860528883070529, count=992)),
#  ('지두', Info(coef=-0.8859092426445433, count=51)),
#  ('오면', Info(coef=-0.8844231003033562, count=36)),
#  ('서만큼은', Info(coef=-0.8808001494662847, count=14)),
#  ('오', Info(coef=-0.8808001494662847, count=14)),
#  ('냐가', Info(coef=-0.8808001494662847, count=14)),
#  ('서나마', Info(coef=-0.8808001494662847, count=14)),
#  ('내고', Info(coef=-0.8808001494662846, count=189)),
#  ('보며', Info(coef=-0.8776028640269462, count=41)),
#  ('걸', Info(coef=-0.8742293301715096, count=20))]

# %%
coefficient = load_lr_coefficient('./rcoef.pkl', as_coef_dict=True)
coefficient
# Out:
# {'온': -0.9374121744058179,
#  '마따나': 1.0,
#  '어져서': -1.0,
#  '였으면': -0.25970007860588096,
#  '은년과': -1.0,
#  '해두는': 1.0,
#  '어줘야': -1.0,
#  '하겠다던': 1.0,
#  '기도': -0.9984061595819308,
#  '어가기': -1.0,
#  '놓는': -0.9799228844627041,
#  '왔기': -1.0,
#  '해보아야': 1.0,
#  '었는가': -1.0,
#  '했음이': 1.0,
#  '이므로': 1.0,
#  '다만': -0.9828634089560663,
#  '준다는': -0.9916773448188826,
#  '될지도': 1.0,
#  '스럽기까지': 1.0,
#  '기두': -0.9688056517481524,
#  '어주기': -1.0,
#  '여서는': -0.8678554927480204,
#  '로': 0.9991348189084643,
#  '이고': 0.9981023746664459,
#  '았던가': -1.0,
#  '일까': 1.0,
#  '지은': 0.7387194126189855,
#  '들어간': -1.0,
#  '내게': -0.6159468009016545,
#  '게야': -1.0,
#  '해왔기': 1.0,
#  '워할': -1.0,
#  '있다고': -0.2483744474135929,
#  '해보라고': 1.0,
#  '는요': 1.0,
#  '께로': 1.0,
#  '부턴가': 1.0,
#  '이라야': 1.0,
#  '에나': 1.0,
#  '수도': -1.0,
#  '섞인': 1.0,
#  '어졌기': -1.0,
#  '었건': -1.0,
#  '층쌓기한': -1.0,
#  '댈': -0.9409541242573974,
#  '에서보다도': 1.0,
#  '으로선': 1.0,
#  '주었지만': -1.0,
#  '함은': 1.0,
#  '아두는': -1.0,
#  '되었는데': 1.0,
#  '수없이': -1.0,
#  '로나마': 1.0,
#  '살': -0.595521298932173,
#  '라거나': -0.09654916793905362,
#  '는가를': -1.0,
#  '어': -0.9997795009066031,
#  '서부터': -0.32307783501690746,
#  '주도록': -1.0,
#  '가지고': -0.9914592628616189,
#  '지만도': -1.0,
#  '직한': -1.0,
#  '야겠다고': -1.0,
#  '에서부터': 0.9944847412719825,
#  '했단': 1.0,
#  '는걸': -1.0,
#  '다고': -0.9997668203348251,
#  '당했던': 1.0,
#  '하여야만': 1.0,
#  '지는가': -1.0,
#  '준': -0.9991972321457451,
#  '이냐의': 1.0,
#  '에서일': 1.0,
#  '기라고': -1.0,
#  '어볼까': -1.0,
#  '했는데': 0.9881443596717088,
#  '버리곤': -1.0,
#  '주길': -1.0,
#  '다운': 1.0,
#  '까를': -1.0,
#  '우니까': -1.0,
#  '주었을': -1.0,
#  '은가': -0.993520832205863,
#  '내기도': -0.6511767857258169,
#  '시려는': -1.0,
#  '셨지만': -1.0,
#  '어나오는': -1.0,
#  '자면': -1.0,
#  '대요': -1.0,
#  '왔는데': -0.9586226588624001,
#  '나구': 1.0,
#  '보고': -0.48048400900891036,
#  '에서보다': 1.0,
#  '이라기보다': 1.0,
#  '세요': -0.9950090227891899,
#  '함에': 1.0,
#  '다기보다는': -1.0,
#  '고는': -0.9938400755983906,
#  '한가를': 1.0,
#  '스럽지만': 1.0,
#  '든가': -0.9653995762572743,
#  '로밖에는': 1.0,
#  '없이는': 1.0,
#  '해놓은': 1.0,
#  '뿐일': 1.0,
#  '음의': -1.0,
#  '해야지': 1.0,
#  '했고': 0.9885819038866314,
#  '한': 0.9992970436398294,
#  '래면': -1.0,
#  '되고는': 1.0,
#  '을만큼': -1.0,
#  '를': 0.9998274763119769,
#  '질': -0.9787570260150475,
#  '에게선': 1.0,
#  '은년의': -1.0,
#  '로서만이': 1.0,
#  '어둔': -1.0,
#  '스럽게도': 1.0,
#  '에': 0.9907038408385025,
#  '허는': 1.0,
#  '롭지가': 1.0,
#  '서라는': -1.0,
#  '으시다면': -1.0,
#  '기까지': -1.0,
#  '려고도': -1.0,
#  '하느냐가': 1.0,
#  '아먹을': -1.0,
#  '받았던': 1.0,
#  '기에서': -1.0,
#  '으려고도': -1.0,
#  '을지': -1.0,
#  '이니까': 1.0,
#  '고보니': -1.0,
#  '되진': 1.0,
#  '려나': -1.0,
#  '는다는': -1.0,
#  '시켰다고': 1.0,
#  '는가에': -1.0,
#  '시키지': 1.0,
#  '버는': 1.0,
#  '애': -0.9901715710246188,
#  '뿐이었던': 1.0,
#  '지나가는': -1.0,
#  '두었다가': -1.0,
#  '에서인지': 1.0,
#  '선가': 0.9110513035690688,
#  '어놓지': -0.9431605784509193,
#  '이라구': 1.0,
#  '시키지는': 1.0,
#  '뿐이라고': 1.0,
#  '박고': 0.3660503866425696,
#  '먹기로': -0.44899899145417854,
#  '었으리라고': -1.0,
#  '이었는지': 1.0,
#  '거니': -1.0,
#  '받지': 0.9628643377022477,
#  '게서야': -1.0,
#  '넌': -0.9178276831505253,
#  '이었어': 1.0,
#  '었노라고': -1.0,
#  '와는': 0.9968981938304067,
#  '었을까': -1.0,
#  '을까': -1.0,
#  '어치우고': -1.0,
#  '죽은': 0.11088834445121937,
#  '지기도': -0.9924235462556427,
#  '타고': -0.07782301222351949,
#  '보지만': -1.0,
#  '어다니며': -1.0,
#  '기가': -0.9995277348844647,
#  '아내야': -1.0,
#  '었나': -1.0,
#  '오지': -1.0,
#  '뿐더러': -1.0,
#  '아졌다': -1.0,
#  '였으니까': 0.1179884628303014,
#  '지만은': -1.0,
#  '시지': -1.0,
#  '해달라고': 1.0,
#  '매': -1.0,
#  '하려고만': 1.0,
#  '느냐의': -1.0,
#  '었단': -1.0,
#  '오기': -0.8263742646257802,
#  '대로만': 0.7864568963097595,
#  '다주고': -1.0,
#  '였지만': 0.09138358335305262,
#  '된다': 1.0,
#  '았다는': -1.0,
#  '하려던': 1.0,
#  '받게': 1.0,
#  '구요': -0.9159354132966245,
#  '을지에': -1.0,
#  '워만': -1.0,
#  '으로부터': 0.9841061682133436,
#  '주었기': -1.0,
#  '였는지': 0.10548778360796315,
#  '기나': -1.0,
#  '하시고': 1.0,
#  '에서와': 1.0,
#  '아졌고': -1.0,
#  '지두': -0.8859092426445433,
#  '해와': 1.0,
#  '께서도': 1.0,
#  '하다보면': 1.0,
#  '듯한': -1.0,
#  '으려고': -1.0,
#  '어질수록': -1.0,
#  '이라면': 0.9907990884403205,
#  '다기보다': -1.0,
#  '아할': -1.0,
#  '한다면서': 1.0,
#  '을망정': -1.0,
#  '이기보다는': 1.0,
#  '까지는': 1.0,
#  '어져야': -1.0,
#  '으려다': -1.0,
#  '걸': -0.8742293301715096,
#  '어보고': -1.0,
#  '당해야': 1.0,
#  '나지': 0.34295137678788895,
#  '겄다고': -1.0,
#  '나오기': -1.0,
#  '버렸다는': -1.0,
#  '아온': -1.0,
#  '셨는지': -1.0,
#  '하자니': 1.0,
#  '하실': 1.0,
#  '놓았던': -0.962683189456158,
#  '여도': -0.977313376170123,
#  '스러웠고': 1.0,
#  '느냐며': -1.0,
#  '어죽을': -1.0,
#  '어준다는': -1.0,
#  '쓰이는': 0.583561689476319,
#  '해보자는': 1.0,
#  '해야겠지만': 1.0,
#  '하라': 1.0,
#  '봤자': -1.0,
#  '으셔': -1.0,
#  '았단': -1.0,
#  '없이': 0.9407317628293717,
#  '놈이': 0.006968710321269865,
#  '네만': -0.9267334165197791,
#  '졌는데': -1.0,
#  '냈다고': -1.0,
#  '하지가': 1.0,
#  '됐다는': 1.0,
#  '리라는': -0.9967130886165126,
#  '해지게': 1.0,
#  '였다면': 0.25018031001118596,
#  '해다': 1.0,
#  '없이도': 1.0,
#  '는데다': -1.0,
#  '어져도': -1.0,
#  '았기에': -1.0,
#  '헌': 1.0,
#  '질까': -1.0,
#  '게라도': -1.0,
#  '가의': 0.8672836982830473,
#  '부터라고': 1.0,
#  '시키면': 1.0,
#  '가가': 0.9395201481770461,
#  '건대': -0.8507176136131749,
#  '전대표가': 1.0,
#  '기까지의': -1.0,
#  '은해': -1.0,
#  '우면서도': -1.0,
#  '올린': -0.918922699289801,
#  '이어서는': 1.0,
#  '이라는데': 1.0,
#  '해진다는': 1.0,
#  '부턴': 1.0,
#  '도가도': -1.0,
#  '었는데': -0.9994405344540865,
#  '아내지': -1.0,
#  '었다고': -0.9995735478087596,
#  '어다니는': -1.0,
#  '러서도': -1.0,
#  '이라니': 1.0,
#  '에서조차도': 1.0,
#  '았을': -1.0,
#  '었다간': -1.0,
#  '깊은': 1.0,
#  '해서야': 1.0,
#  '우신': -1.0,
#  '워졌다고': -1.0,
#  '아하지': -1.0,
#  '하게끔': 1.0,
#  '여지는': -1.0,
#  '서껀': 1.0,
#  '됐고': 1.0,
#  '이거니와': 1.0,
#  '잡고': 0.9101224109829432,
#  '보니': -0.9965953732432296,
#  '주고': -0.9928035150750342,
#  '보려고': -1.0,
#  '했으니까': 1.0,
#  '았건만': -1.0,
#  '됐을': 1.0,
#  '임에': 1.0,
#  '느라': -0.9985271969607581,
#  '는다든지': -1.0,
#  '해보고자': 1.0,
#  '어진다면': -1.0,
#  '해주기를': 1.0,
#  '하던': 0.979750915315599,
#  '도록': -1.0,
#  '만을': 0.990795062697616,
#  '스럽다는': 1.0,
#  '삼은': 1.0,
#  '어감에': -1.0,
#  '됨을': 1.0,
#  '망정': -1.0,
#  '싶어': 1.0,
#  '어한다는': -1.0,
#  '자면서': -1.0,
#  '버리지는': -0.918922699289801,
#  '자구': -1.0,
#  '어나는': -1.0,
#  '이어서인지': 1.0,
#  '겠느냐는': -1.0,
#  '하는가는': 1.0,
#  '하시며': 1.0,
#  '어먹고': -1.0,
#  '주지는': -1.0,
#  '시길': -1.0,
#  '버릴': -1.0,
#  '어와': -1.0,
#  '워하던': -1.0,
#  '스러워질': 1.0,
#  '했다기보다는': 1.0,
#  '으로': 0.995800322882002,
#  '지니': -1.0,
#  '까지나': 1.0,
#  '이지': 1.0,
#  '려니와': -0.6475848117893315,
#  '만의': 1.0,
#  '워있는': -1.0,
#  '워요': -1.0,
#  '어올려': -1.0,
#  '더라는': -0.9952873641055545,
#  '져': -0.9959098896459879,
#  '으면서': -1.0,
#  '하듯': 1.0,
#  '놓기': -0.9535705616395668,
#  '되었는가': 1.0,
#  '보자고': -0.9688056517481524,
#  '고자': -0.9994745496809705,
#  '일까를': 1.0,
#  '었던가': -1.0,
#  '에서만은': 1.0,
#  '어내려': -1.0,
#  '해가며': 1.0,
#  '것이': -0.7307592452190438,
#  '스럽던': 1.0,
#  '스러움과': 1.0,
#  '느냐에': -1.0,
#  '아다': -1.0,
#  '보자는': -1.0,
#  '워': -1.0,
#  '는다니': -1.0,
#  '아진다는': -1.0,
#  '아지고': -1.0,
#  '에서마저': 1.0,
#  '었다지만': -1.0,
#  '잔': -1.0,
#  '은년은': -1.0,
#  '해오던': 1.0,
#  '아있지': -1.0,
#  '으리란': -1.0,
#  '임에도': 1.0,
#  '지먼': -0.8586451273290011,
#  '스러움으로': 1.0,
#  '해내지': 1.0,
#  '라고는': 0.5722728164527692,
#  '셨나': -1.0,
#  '하고서는': 1.0,
#  '고간': -1.0,
#  '당하여': 1.0,
#  '어주어': -1.0,
#  '하다시피': 1.0,
#  '되어': 1.0,
#  '가': 0.9723793005293764,
#  '다곤': -1.0,
#  '라도': 0.7536172622881769,
#  '이려니': 1.0,
#  '이다': 1.0,
#  '아들어': -1.0,
#  '산': -0.9267334165197791,
#  '할려고': 1.0,
#  '되었다고': 1.0,
#  '기좋은': -1.0,
#  '겠냐고': -1.0,
#  '만이': 0.9897680732156456,
#  '니까': -0.8422997393928967,
#  '짓게': 1.0,
#  '했었지만': 1.0,
#  '했었다고': 1.0,
#  '받아': 0.8088745069942513,
#  '하며': 0.9803232876726332,
#  '아둔': -1.0,
#  '었다고나': -1.0,
#  '었는데도': -1.0,
#  '아주는': -1.0,
#  '어진다고': -1.0,
#  '어짐을': -1.0,
#  '말': -0.8894625978993094,
#  '먹지': -1.0,
#  '라기보다': 1.0,
#  '해내는': 1.0,
#  '였음을': 0.010859466443931766,
#  '라고까지': 0.31065765890223446,
#  '어두기로': -1.0,
#  '았었다고': -1.0,
#  '나온': -0.6804864194445551,
#  '는가의': -1.0,
#  '이루': 1.0,
#  '하고만': 1.0,
#  '만에': 0.889575023522031,
#  '게아니라': -1.0,
#  '로웠던': 1.0,
#  '론': 1.0,
#  '토록': 1.0,
#  '는데도': -1.0,
#  '듯하게': -1.0,
#  '께서': 1.0,
#  '웠지만': -1.0,
#  '시켜줄': 1.0,
#  '았을까': -1.0,
#  '엔': 1.0,
#  '으니께': -1.0,
#  '어앉아': -1.0,
#  '짓고': 1.0,
#  '하였으나': 1.0,
#  '는디': -1.0,
#  '보내고': -0.8263742646257802,
#  '대기': -0.9385694465353448,
#  '이겠지': 1.0,
#  '론가': 1.0,
#  '아주고': -1.0,
#  '롭기': 1.0,
#  '겠구나': -1.0,
#  '시다': -0.9660179858517861,
#  '만큼이나': 1.0,
#  '한다구': 1.0,
#  '지에': -1.0,
#  '해지며': 1.0,
#  '보며': -0.8776028640269462,
#  '어쓰기': -1.0,
#  '게까지': -0.9868830119259813,
#  '도끝도': 1.0,
#  '을지를': -1.0,
#  '스럽고도': 1.0,
#  '잡지': 1.0,
#  '와같은': 1.0,
#  '하셔도': 1.0,
#  '보다두': 1.0,
#  '아지게': -1.0,
#  '되면서부터': 1.0,
#  '았고': -1.0,
#  '만으로는': 1.0,
#  '으로서': 0.966114231619645,
#  '어가야': -1.0,
#  '롭다는': 1.0,
#  '야겠다': -1.0,
#  '이었겠지만': 1.0,
#  '다놓고': -1.0,
#  '시지만': -1.0,
#  '하는가를': 1.0,
#  '나가지': -0.9562419503175186,
#  '았음을': -1.0,
#  '마저': 1.0,
#  '스럽기': 1.0,
#  '었듯이': -1.0,
#  '는데요': -1.0,
#  '시켜야': 1.0,
#  '셔야': -1.0,
#  '아지지': -1.0,
#  '과는': 0.9979571762395137,
#  '이라곤': 1.0,
#  '하듯이': 1.0,
#  '라는데': -0.3853865429228216,
#  '어지지도': -1.0,
#  '어넣는': -1.0,
#  '서야': -0.8032330030797656,
#  '아빠진': -1.0,
#  '시게': -0.9901715710246188,
#  '을려고': -1.0,
#  '애서': -0.962683189456158,
#  '어야지': -1.0,
#  '았는': -1.0,
#  '했거나': 1.0,
#  '에서뿐만': 1.0,
#  '아내며': -1.0,
#  '오면서': -0.9471131779768764,
#  '지며': -0.9461774766874674,
#  '어나가지': -1.0,
#  '겠는지': -1.0,
#  '이던': 1.0,
#  '았더니만': -1.0,
#  '하여': 0.9988191382066381,
#  '까장': 1.0,
#  '먹이는': 0.5477536931929817,
#  '쓰지': 0.8847349812900274,
#  '었잖아': -1.0,
#  '만치도': 1.0,
#  '스러운지': 1.0,
#  '았는지를': -1.0,
#  '이란': 0.9897467967233727,
#  '어먹는': -1.0,
#  '어버리면': -1.0,
#  '전의장은': 1.0,
#  '어오면': -1.0,
#  '되었기': 1.0,
#  '띤': 1.0,
#  '했으니': 1.0,
#  '되는지': 1.0,
#  '로든': 1.0,
#  '쓰기': 0.7987155120469387,
#  '아요': -1.0,
#  '보던': -0.8586451273290011,
#  '만도': 0.7889056685448246,
#  '으믄': -1.0,
#  '에만도': 1.0,
#  '어올릴': -1.0,
#  '라든지': 0.8319451823599369,
#  '어지지는': -1.0,
#  '겠노라고': -1.0,
#  '다보니': -1.0,
#  '와서': -0.8441628272385072,
#  '아하는': -1.0,
#  '됨과': 1.0,
#  '움의': -1.0,
#  '까지와': 1.0,
#  '다': -0.9293041782509179,
#  '전대표는': 1.0,
#  '어모아': -1.0,
#  '에부터': 1.0,
#  '어두': -1.0,
#  '올라가': -1.0,
#  '으먼': -1.0,
#  '했다며': 1.0,
#  '먹으며': -0.9586226588624001,
#  '만': 0.9672646720806028,
#  '다워야': 1.0,
#  '로도': 1.0,
#  '하든지': 1.0,
#  '스러웠지만': 1.0,
#  '아져야': -1.0,
#  '갔을': -0.8441628272385072,
#  '한테는': 1.0,
#  '조차': 0.993002519137934,
#  '는가라는': -1.0,
#  '기': -0.9976370851668035,
#  '었는지도': -1.0,
#  '였다가': -0.5006787090925042,
#  '시구': -0.9732022773918881,
#  '해지는': 1.0,
#  '나마나한': -1.0,
#  '하다는': 1.0,
#  '시킬': 1.0,
#  '함과': 1.0,
#  '다라고': -0.8416004182872371,
#  '다보면': -1.0,
#  '어냈다는': -1.0,
#  '운가': -1.0,
#  '할려구': 1.0,
#  '은요': 1.0,
#  '해지자': 1.0,
#  '느냐는': -1.0,
#  '여서도': -0.9431605784509193,
#  '로의': 1.0,
#  '빠른': 1.0,
#  '인지조차': 1.0,
#  '았다고는': -1.0,
#  '으면서까지': -1.0,
#  '당하고': 0.9716666394657052,
#  '어하고': -1.0,
#  '어져가고': -1.0,
#  '마다에': 1.0,
#  '벌러': 1.0,
#  '하기조차': 1.0,
#  '이랄': 1.0,
#  '말고': 1.0,
#  '어들고': -1.0,
#  '받기': 0.9010062326994239,
#  '만큼의': 1.0,
#  '서서': -0.8657731306619115,
#  '치며': 0.8672836982830472,
#  '았던지': -1.0,
#  '아하고': -1.0,
#  '었습니다': -1.0,
#  '준다고': -1.0,
#  '었고': -0.9996120515823723,
#  '로나': 1.0,
#  '움으로': -1.0,
#  '어만': -1.0,
#  '어나가야': -1.0,
#  '셨다가': -1.0,
#  '당하게': 1.0,
#  '다가': -0.965036115890625,
#  '되었다가': 1.0,
#  '이고도': 1.0,
#  '워하지': -1.0,
#  '가고': -0.957065386513816,
#  '하단': 1.0,
#  '아두어야': -1.0,
#  '해오고': 1.0,
#  '어두는': -1.0,
#  '이사': 1.0,
#  '려구': -1.0,
#  '할수록': 1.0,
#  '되어도': 1.0,
#  '음도': -1.0,
#  '스럽기만': 1.0,
#  '워서도': -1.0,
#  '내야만': -1.0,
#  '으려': -1.0,
#  '져도': -1.0,
#  '어짐에': -1.0,
#  '함으로써만': 1.0,
#  '겠느냐': -1.0,
#  '겠다니': -1.0,
#  '었더라면': -1.0,
#  '해야겠다고': 1.0,
#  '실지': -1.0,
#  '닿는': -0.962683189456158,
#  '까봐': -1.0,
#  '하자고': 1.0,
#  '은데다': -1.0,
#  '신다구': -1.0,
#  '고': -0.9973716513207566,
#  '라느니': -0.44899899145417854,
#  '인지는': 1.0,
#  '데다가': -1.0,
#  '가를': 0.5025082813699683,
#  '고보면': -1.0,
#  '까라는': -0.9331714559679727,
#  '인즉슨': 1.0,
#  '게': -0.9864383012828826,
#  '인지': 0.9947279892126415,
#  '었다던': -1.0,
#  '맡고': 0.5477536931929817,
#  '었던들': -1.0,
#  '되어질': 1.0,
#  '받기로': 1.0,
#  '아라': -1.0,
#  '입고': -0.7359524579974337,
#  '구서는': -1.0,
#  '임에는': 1.0,
#  '지지만': -1.0,
#  '하고서도': 1.0,
#  '하더라는': 1.0,
#  '이다시피': 1.0,
#  '아야': -0.999796616987969,
#  '어넣고': -1.0,
#  '어버리지': -1.0,
#  '잘': -0.8894625978993094,
#  '되려는': 1.0,
#  '아야겠다는': -1.0,
#  '디': -0.9222386550658336,
#  '아봤자': -1.0,
#  '해놓고': 1.0,
#  '다투어': 1.0,
#  '이다라고': 1.0,
#  '해주듯': 1.0,
#  '졌기': -1.0,
#  '지을': 1.0,
#  '아나선': -1.0,
#  '오니': -1.0,
#  '이었다고': 0.9630383203469777,
#  '하라면': 1.0,
#  '아두': -1.0,
#  '었다기보다는': -1.0,
#  '에서도': 0.9990677312994536,
#  '으나마나': -1.0,
#  '나가게': -1.0,
#  '다고까지': -1.0,
#  '아둬야': -1.0,
#  '버려야': -1.0,
#  '해보고': 1.0,
#  '려는지': -1.0,
#  '대면서': -1.0,
#  '어졌으며': -1.0,
#  '해가고': 1.0,
#  '만치': 0.1179884628303014,
#  '할수': 1.0,
#  '어올라가': -1.0,
#  '나기': 0.20668065080437642,
#  '되었으므로': 1.0,
#  '하기보다는': 1.0,
#  '에야': 1.0,
#  '였다': -0.5413102411678166,
#  '더라도': -0.9997405568869362,
#  '으라구': -1.0,
#  '어넣어': -1.0,
#  '하고자': 1.0,
#  '서건': -0.8441628272385072,
#  '으면서도': -1.0,
#  '에서라면': 1.0,
#  '가하면': -1.0,
#  '아해서': -1.0,
#  '고나면': -1.0,
#  '먼': -0.9385694465353448,
#  '했다': 1.0,
#  '자': -0.9986800547161694,
#  '갔다가': -0.44899899145417854,
#  '더란': -0.9854806682050405,
#  '났다': 1.0,
#  '기에는': -1.0,
#  '냐고': -0.5675489389894074,
#  '어보니까': -1.0,
#  '임과': 1.0,
#  '우나': -1.0,
#  '답지': 1.0,
#  '어지는': -1.0,
#  '렀을': -1.0,
#  '보아': -1.0,
#  '기만을': -1.0,
#  '했겠지만': 1.0,
#  '신다는': -1.0,
#  '타는': 1.0,
#  '아주면': -1.0,
#  '었다구': -1.0,
#  '하고서': 1.0,
#  '됨으로써': 1.0,
#  '스러움을': 1.0,
#  '하게는': 1.0,
#  '지마는': -0.9478386356899433,
#  '아먹고': -1.0,
#  '된다며': 1.0,
#  '어나가는': -1.0,
#  '에서만도': 1.0,
#  '야': -0.9167852302548157,
#  '아쥐고': -1.0,
#  '시킴과': 1.0,
#  '음과': -1.0,
#  '였던': 0.19828293842922717,
#  '마다': 1.0,
#  '답시고': -1.0,
#  '뿐이라는': 1.0,
#  '하다고는': 1.0,
#  '워하는': -1.0,
#  '돈을': -1.0,
#  '된데': 1.0,
#  '버리지': -0.962683189456158,
#  '하시게': 1.0,
#  '로밖에': 1.0,
#  '으로부터는': 1.0,
#  '기로': -1.0,
#  '느냐면서': -1.0,
#  '겠단': -1.0,
#  '되어지는': 1.0,
#  '였는가': -0.3733284550731789,
#  '하니': 1.0,
#  '올릴': -0.7750097037734404,
#  '이리라': 1.0,
#  '았는지': -1.0,
#  '대로라면': 1.0,
#  '졌다는': -1.0,
#  '시기도': -1.0,
#  '냐면은': -0.41014930693802637,
#  '았느냐는': -1.0,
#  '한테서': 1.0,
#  '됐음을': 1.0,
#  '려니까': -1.0,
#  '두기': -1.0,
#  '되길': 1.0,
#  '소': -0.9741143768654731,
#  '아보려고': -1.0,
#  '시려고': -1.0,
#  '으시며': -1.0,
#  '함으로써': 1.0,
#  '래야': -0.8040013319207225,
#  '아보니': -1.0,
#  '시킨다면': 1.0,
#  '키로': 1.0,
#  '받는다는': 1.0,
#  '어나가기': -1.0,
#  '였단': 0.5052083848782234,
#  '시라고': -0.9667605912544323,
#  '주시는': -1.0,
#  '어진': -1.0,
#  '삼아': 1.0,
#  '이라고도': 1.0,
#  '되지만': 1.0,
#  '워하며': -1.0,
#  '지지를': -1.0,
#  '한테': 1.0,
#  '받으러': 1.0,
#  '기를': -0.9996567061494179,
#  '있을': -0.36238273083326983,
#  '면은': -0.9781676303041252,
#  '나가서': -0.8894625978993094,
#  '냐면': -0.32284512628852263,
#  '주시던': -1.0,
#  '래': -0.7597814823500575,
#  '다마는': -1.0,
#  '련만': -1.0,
#  '어주기로': -1.0,
#  '되면서': 1.0,
#  '갔고': -1.0,
#  '해보기로': 1.0,
#  '어버렸다고': -1.0,
#  '자고': -0.9983900122839763,
#  '스러움에': 1.0,
#  '올': -0.855485104910356,
#  '야만': -0.996978604129839,
#  '시키면서': 1.0,
#  '일': 0.975338674800843,
#  '고선': -1.0,
#  '한텐': 1.0,
#  '으리라고는': -1.0,
#  '되니': 1.0,
#  '한다기보다는': 1.0,
#  '스럽지': 1.0,
#  '였으므로': 0.02235092944199764,
#  '터를': -1.0,
#  '했어야': 1.0,
#  '으': -0.059725703753943156,
#  '하기라도': 1.0,
#  '했는지는': 1.0,
#  '다고는': -1.0,
#  '꾸는': 1.0,
#  '인들': 1.0,
#  '시기만': -1.0,
#  '한다고는': 1.0,
#  '신다면': -1.0,
#  '어내리는': -1.0,
#  '드리면': -0.059725703753943156,
#  '하기는': 0.9894095857843401,
#  '쓰기의': 0.8096431046176613,
#  '하기의': 1.0,
#  '고를': -0.8263742646257803,
#  '해지기도': 1.0,
#  '으므로': -1.0,
#  '았으니': -1.0,
#  '구는': -1.0,
#  '스러워야': 1.0,
#  '뿐이': 1.0,
#  '겠네': -0.9722235533233115,
#  '인지도': 1.0,
#  '워서': -1.0,
#  '주면서': -1.0,
#  '어보아도': -1.0,
#  '았는지도': -1.0,
#  '한다고도': 1.0,
#  '하시면서': 1.0,
#  '든데': -1.0,
#  '어라': -1.0,
#  '도때도': 1.0,
#  '어가지고': -1.0,
#  '일는지도': 1.0,
#  '되는지를': 1.0,
#  '롭게': 1.0,
#  '어지지가': -1.0,
#  '려다가': -1.0,
#  '어온': -1.0,
#  '워지면': -1.0,
#  '을까를': -1.0,
#  '아올리는': -1.0,
#  '야겠지만': -1.0,
#  '시켜서': 1.0,
#  '는다': -1.0,
#  '해주면': 0.8024948271335807,
#  '었을': -1.0,
#  '우러': -1.0,
#  '웠다': -1.0,
#  '입은': -0.025295040446776534,
#  '기와': -1.0,
#  '돼서는': 1.0,
#  '길': -1.0,
#  '만큼': 0.7139761423691169,
#  '스러우며': 1.0,
#  '시키려': 1.0,
#  '더라두': -1.0,
#  '한다': 0.9861820713163731,
#  '되게': 1.0,
#  '밖에는': 1.0,
#  '아낼': -1.0,
#  '에서만': 1.0,
#  '졌고': -1.0,
#  '아올린': -1.0,
#  '다는게': -1.0,
#  '보았지만': -1.0,
#  '되었음에도': 1.0,
#  '에다가': 0.9867728339120726,
#  '대': -1.0,
#  '한다든가': 1.0,
#  '칠': 0.7568389353410812,
#  '테니까': -1.0,
#  '하자는': 1.0,
#  '하기에도': 1.0,
#  '이니만큼': 1.0,
#  '됐지만': 1.0,
#  '놓은': -0.9923318773671066,
#  '을래': -1.0,
#  '이랄까': 1.0,
#  '지질': -0.9535705616395668,
#  '더니': -0.9972658477951641,
#  '임은': 1.0,
#  '아서가': -1.0,
#  '어들어가': -1.0,
#  '겠으나': -0.9891940384083814,
#  '이냐에': 1.0,
#  '는데': -1.0,
#  '주거나': -1.0,
#  '었구나': -1.0,
#  '어한': -1.0,
#  '어지게': -1.0,
#  '로든지': 1.0,
#  '든간에': -0.7503958240874917,
#  '게든지': -1.0,
#  '밖에': 0.9913584329737697,
#  '서든': -0.7560151666330984,
#  '오르는': -0.9505517941630359,
#  '시키거나': 1.0,
#  '스럽기는': 1.0,
#  '아가면서': -1.0,
#  '에게든': 1.0,
#  '하지를': 1.0,
#  '셨다고': -1.0,
#  '집': 0.6837287093478985,
#  '끓는': 1.0,
#  '어오는': -1.0,
#  '아두었던': -1.0,
#  '보는': -0.9095850648954715,
#  '시다가': -1.0,
#  '시던': -1.0,
#  '서든지': -0.7126760222804542,
#  '기란': -1.0,
#  '받을': 0.9422220272590107,
#  '라지만': 0.640491999190529,
#  '에게도': 1.0,
#  '없을': 1.0,
#  '더래두': -1.0,
#  '인가에': 1.0,
#  '어있던': -1.0,
#  '아왔던': -1.0,
#  '어넣으며': -1.0,
#  '싶은': 1.0,
#  '어주며': -1.0,
#  '하신다면': 1.0,
#  '시는데': -1.0,
#  '니깐': -0.8742293301715096,
#  '았냐고': -1.0,
#  '주려는': -1.0,
#  '버렸다고': -1.0,
#  '이었던지': 1.0,
#  '십시오': -1.0,
#  '습니다만': -1.0,
#  '잡은': 0.8808170461331736,
#  '해나갈': 1.0,
#  '받는': 0.9663670354166046,
#  '다기에': -1.0,
#  '것': -0.5561811654065566,
#  '한데다': 1.0,
#  '느니': -1.0,
#  '해하던': 1.0,
#  '으로부터의': 1.0,
#  '서라기보다는': -1.0,
#  '았지': -1.0,
#  '과도': 1.0,
#  '다오면': -1.0,
#  '쓰기는': 1.0,
#  '짓지': 1.0,
#  '겠습니다만': -0.9586226588624001,
#  '되었다면': 1.0,
#  '서만': -0.8610660238090119,
#  '쓴': -0.3941299205769083,
#  '시켜주는': 1.0,
#  '하는지도': 1.0,
#  '며': -0.9823929122563203,
#  '일뿐더러': 1.0,
#  '라두': 1.0,
#  '다주는': -1.0,
#  '이었으며': 1.0,
#  '다할': -1.0,
#  '웠고': -1.0,
#  '해볼': 0.9801250059926577,
#  '는데서': -1.0,
#  '먹게': -0.8441628272385072,
#  '아야겠다고': -1.0,
#  '한다고': 1.0,
#  '으셔서': -1.0,
#  '해달라는': 1.0,
#  '했지만': 0.980660924141144,
#  '하는지에': 1.0,
#  '흘려': 1.0,
#  '겠느냐며': -1.0,
#  '됐다고': 1.0,
#  '잡아': 0.6634935078585975,
#  '했잖아': 1.0,
#  '하느냐고': 1.0,
#  '까지가': 1.0,
#  '가기': -0.8089255959131322,
#  '고오는': -1.0,
#  ...}
